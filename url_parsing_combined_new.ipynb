# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from urllib.parse import urlparse
import re
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from tld import get_tld

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('Training Data/Phishing_Mitre_Dataset_Summer_of_AI.csv')
df
# Out:
#       create_age(months)  expiry_age(months)  update_age(days)  \
# 0                     -1                  -1                -1
# 1                    212                  16               663
# 2                     -1                  -1                -1
# 3                    198                   6               186
# 4                    240                  24              1684
# ...                  ...                 ...               ...
# 4794                  52                   8               118
# 4795                  -1                  -1                -1
# 4796                  -1                  -1                -1
# 4797                  -1                  -1                -1
# 4798                 172                  68               745
#
#                                                     URL  Label
# 0     http://account-google-com.ngate.my/c44cca40176...      1
# 1                  http://www.coffeespecialties.com/...      0
# 2     http://black.pk/wp-content/2013/04/bp.postale/...      1
# 3                       http://atomicsoda.com/manutd...      0
# 4                       http://bostoncoffeecake.com/...      0
# ...                                                 ...    ...
# 4794  http://aridfoods.com/V4/MGen/F97a8a294cf7c5e90...      1
# 4795                         http://www.mazda.co.jp/...      0
# 4796  http://www.fotografaemsaopaulo.com.br/wp-admin...      1
# 4797  http://agenda.wehrensarl.ch/libraries/joomla/h...      1
# 4798               http://www.waterfrontrecords.com/...      0
#
# [4799 rows x 5 columns]

# %% [markdown]
# # Feature Creation

# %% [markdown]
# ## URL Length

# %%
df['url_length'] = df['URL'].apply(len)

# %% [markdown]
# ## URL Entropy

# %%
def entropy(url_string):
        string = url_string.strip()
        prob = [float(string.count(c)) / len(string) for c in dict.fromkeys(list(string))]
        entropy = sum([(p * math.log(p) / math.log(2.0)) for p in prob])
        return abs(entropy)

df['url_entropy'] = df['URL'].apply(entropy)

# %% [markdown]
# ## Third Level Domain

# %%
def has_www(url_string):
    if (url_string.find('www.') == -1):
        return False
    else:
        return True
    
def find_between(url_string):
    try:
        return get_tld(url_string, fix_protocol=True)
    except:
        return ''

df['3rd_level_domain'] = df['URL'].apply(has_www)

# %% [markdown]
# ## Non Alpha Characters

# %%
df['count_non_alpha'] = df['URL'].str.findall(r'[^a-zA-Z]').str.len()

# %% [markdown]
# # One Hot Encode and Drop Unnecessary Columns

# %%
df = pd.get_dummies(df, columns=['3rd_level_domain'])

# %%
y_df = df['Label']
X_df = df.drop(['Label','URL'],axis=1)
X_df
# Out:
#       create_age(months)  expiry_age(months)  update_age(days)  url_length  \
# 0                     -1                  -1                -1          70
# 1                    212                  16               663          36
# 2                     -1                  -1                -1          73
# 3                    198                   6               186          31
# 4                    240                  24              1684          31
# ...                  ...                 ...               ...         ...
# 4794                  52                   8               118          73
# 4795                  -1                  -1                -1          26
# 4796                  -1                  -1                -1          73
# 4797                  -1                  -1                -1          73
# 4798                 172                  68               745          36
#
#       url_entropy  3rd_level_domain_False  3rd_level_domain_True  \
# 0        4.612783                       1                      0
# 1        3.819114                       0                      1
# 2        4.370385                       1                      0
# 3        3.695501                       1                      0
# 4        3.760017                       1                      0
# ...           ...                     ...                    ...
# 4794     4.742582                       1                      0
# 4795     3.507380                       0                      1
# 4796     4.579566                       0                      1
# 4797     4.441882                       1                      0
# 4798     3.805497                       0                      1
#
#       count_non_alpha
# 0                  32
# 1                   9
# 2                  35
# 3                   8
# 4                   8
# ...               ...
# 4794               31
# 4795               10
# 4796               21
# 4797               18
# 4798                9
#
# [4799 rows x 8 columns]

# %% [markdown]
# # Split Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, train_size=0.8, test_size=0.2)

# %%
X_train
# Out:
#       create_age(months)  expiry_age(months)  update_age(days)  \
# 807                  226                  14                 8
# 3265                  -1                  -1                -1
# 2426                  19                   5               576
# 3800                  24                  12               480
# 2182                 165                  63               303
# ...                  ...                 ...               ...
# 4608                  99                   9               104
# 4761                  -1                  -1                -1
# 4242                  30                   6               169
# 1716                 196                   8               133
# 3776                 199                   5               217
#
#                                                     URL  url_length  \
# 807           http://secure.square.loginidqx.usa.cc/...          41
# 3265  http://www.nichuizen.co.za/errors/sess/6fcfacd...          73
# 2426  http://service-paypal-information.sweddy.com/S...          73
# 3800  http://citibuildersgroup.com/account-updating-...          73
# 2182                       http://broadwayworld.com/...          28
# ...                                                 ...         ...
# 4608                http://practical-management.com/...          35
# 4761               http://www.eloahair.com.br/Zone1/...          36
# 4242                    http://kingjchild.com/mu.php...          31
# 1716  http://www.orpheuscomputing.com/PCworks-comput...          72
# 3776                     http://www.indoflorist.com/...          30
#
#       url_entropy  3rd_level_domain_False  3rd_level_domain_True  \
# 807      4.054481                       1                      0
# 3265     4.583545                       0                      1
# 2426     4.876478                       1                      0
# 3800     4.517042                       1                      0
# 2182     3.824863                       1                      0
# ...           ...                     ...                    ...
# 4608     3.864578                       1                      0
# 4761     3.974938                       0                      1
# 4242     3.861477                       1                      0
# 1716     4.303567                       0                      1
# 3776     3.819251                       0                      1
#
#       count_non_alpha
# 807                11
# 3265               29
# 2426               16
# 3800               18
# 2182                8
# ...               ...
# 4608                9
# 4761               12
# 4242                9
# 1716               14
# 3776                9
#
# [3839 rows x 9 columns]

# %%
X_test
# Out:
#       create_age(months)  expiry_age(months)  update_age(days)  \
# 2584                 262                   2               326
# 1467                 194                  46                81
# 824                  226                  14                 8
# 3182                  -1                  -1                -1
# 4452                 159                  21               114
# ...                  ...                 ...               ...
# 646                  197                  19               217
# 4268                 184                   8               114
# 3904                 109                  11                33
# 379                    3                   9                 3
# 3078                  -1                  -1                -1
#
#                                                     URL  url_length  \
# 2584         http://www.iop.org/EJ/journal/0031-9155...          42
# 1467                      http://maths4cet.150m.com/...          29
# 824   http://hiroba.dqx.jp.zicrl.usa.cc/account/app/...          63
# 3182  http://kor.nkhumanrights.or.kr/campaign/region...          73
# 4452                          http://www.doneex.com/...          25
# ...                                                 ...         ...
# 646                         http://www.balmzara.com/...          27
# 4268             http://www.trainingpia.com/flash/uk...          38
# 3904  http://www.heathervictoriaheld.com/wp-includes...          64
# 379                      http://fasonery.net/machine...          30
# 3078     http://www.oswego.edu/~economic/workpap.htm...          46
#
#       url_entropy  3rd_level_domain_False  3rd_level_domain_True  \
# 2584     4.327340                       0                      1
# 1467     3.715932                       1                      0
# 824      4.222226                       1                      0
# 3182     4.574572                       1                      0
# 4452     3.559080                       0                      1
# ...           ...                     ...                    ...
# 646      3.648432                       0                      1
# 4268     4.073475                       0                      1
# 3904     4.309172                       0                      1
# 379      3.872906                       1                      0
# 3078     4.067177                       0                      1
#
#       count_non_alpha
# 2584               20
# 1467               13
# 824                16
# 3182               20
# 4452                9
# ...               ...
# 646                 9
# 4268               10
# 3904               12
# 379                 8
# 3078               12
#
# [960 rows x 9 columns]

# %%
y_train
# Out:
# 807     1
# 3265    1
# 2426    1
# 3800    1
# 2182    0
#        ..
# 4608    0
# 4761    1
# 4242    1
# 1716    0
# 3776    0
# Name: Label, Length: 3839, dtype: int64

# %%
y_test
# Out:
# 2584    0
# 1467    0
# 824     1
# 3182    1
# 4452    0
#        ..
# 646     0
# 4268    1
# 3904    1
# 379     1
# 3078    0
# Name: Label, Length: 960, dtype: int64
